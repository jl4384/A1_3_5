# %%
from __future__ import print_function
if input('One character: ') == '!':
    print('Wow', end='!')
# Out:
# One character: !
# Wow!

# %%
slogan = 'My school is the best'
type(slogan)
# Out:
# str

# %%
slogan
# Out:
# 'My school is the best'

# %%
type('tr' + "y this")
# Out:
# str

# %%
type('tr' + 5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-2f08ff03ed78> in <module>
# ----> 1 type('tr' + 5)
#
# TypeError: can only concatenate str (not "int") to str

# %%
slogan[0]
# Out:
# 'M'

# %%
slogan[2]
# Out:
# ' '

# %%
slogan[8]
# Out:
# 'l'

# %%
slogan[26]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-e2d5dacaaa69> in <module>
# ----> 1 slogan[26]
#
# IndexError: string index out of range

# %%
slogan[-2]
# Out:
# 's'

# %%
slogan[0:5]
# Out:
# 'My sc'

# %%
slogan[5:21]
# Out:
# 'hool is the best'

# %%
slogan[:5]
# Out:
# 'My sc'

# %%
slogan[17:21]
# Out:
# 'best'

# %%
slogan[:13] + 'awesome!'
# Out:
# 'My school is awesome!'

# %%
len(slogan)
# Out:
# 21

# %%
activity = 'theater'

# %%
len(activity)
# Out:
# 7

# %%
activity[0 : len(activity)-1]
# Out:
# 'theate'

# %%
'test goo' in 'Greatest good for the greatest number!'
# Out:
# True

# %%
def how_eligible(essay)
